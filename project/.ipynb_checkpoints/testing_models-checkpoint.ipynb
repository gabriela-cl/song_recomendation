# %% [markdown]
# # Evaluation Metrics
#
# Choosing the best model

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.preprocessing import StandardScaler

df = pd.read_csv('df_concat.csv')

# %%
df
# Out:
#       Unnamed: 0.1  danceability  energy  key  loudness  mode  speechiness  \
# 0                0        0.6110  0.3660    4   -10.890     0       0.2910
# 1                1        0.5120  0.5110    2    -8.645     0       0.0300
# 2                2        0.7970  0.3550   11   -14.592     0       0.0651
# 3                3        0.4260  0.2310    2   -16.066     1       0.0359
# 4                4        0.5080  0.2790    6   -15.586     0       0.0384
# ...            ...           ...     ...  ...       ...   ...          ...
# 2686          2704        0.2400  0.0834    6   -29.545     0       0.0499
# 2687          2705        0.4050  0.3180    9   -17.140     1       0.0565
# 2688          2706        0.2910  0.0981    8   -23.156     1       0.0398
# 2689          2707        0.0992  0.2260    9   -14.840     0       0.0339
# 2690          2708        0.3390  0.0937    2   -20.267     1       0.0394
#
#       acousticness  instrumentalness  liveness  valence    tempo  \
# 0            0.874          0.000515    0.0838   0.5930  146.052
# 1            0.662          0.000199    0.2090   0.5890   89.499
# 2            0.872          0.000057    0.0857   0.9610   87.574
# 3            0.740          0.000000    0.1720   0.6670  177.980
# 4            0.783          0.000000    0.1400   0.7280   83.261
# ...            ...               ...       ...      ...      ...
# 2686         0.978          0.944000    0.0804   0.1880  169.621
# 2687         0.938          0.723000    0.2840   0.3420  151.434
# 2688         0.950          0.865000    0.2750   0.1940  138.168
# 2689         0.937          0.903000    0.1830   0.0605   79.518
# 2690         0.931          0.293000    0.2520   0.4580  123.048
#
#                 type                      id  \
# 0     audio_features  1ygVkGM0Uk0M7ULenlZGaf
# 1     audio_features  6U03Orwr5Dxt8jahLnQpYV
# 2     audio_features  2MzS7IK7ZXuk48Btb3EDMy
# 3     audio_features  4pSSmEzKzGo6ehVriMb77D
# 4     audio_features  3LhM43JzrSMUgTzs7wfn0u
# ...              ...                     ...
# 2686  audio_features  4VVEfBXep7FdOt524jkfLF
# 2687  audio_features  7hOLwSaTSkrqxSMzj4bXI1
# 2688  audio_features  76i4IBw3KsuDw783tvHB0e
# 2689  audio_features  53ann6bENp7BF8uklrzQAp
# 2690  audio_features  0qFZYO72iBOhW7X6KbL44Q
#
#                                        uri  \
# 0     spotify:track:1ygVkGM0Uk0M7ULenlZGaf
# 1     spotify:track:6U03Orwr5Dxt8jahLnQpYV
# 2     spotify:track:2MzS7IK7ZXuk48Btb3EDMy
# 3     spotify:track:4pSSmEzKzGo6ehVriMb77D
# 4     spotify:track:3LhM43JzrSMUgTzs7wfn0u
# ...                                    ...
# 2686  spotify:track:4VVEfBXep7FdOt524jkfLF
# 2687  spotify:track:7hOLwSaTSkrqxSMzj4bXI1
# 2688  spotify:track:76i4IBw3KsuDw783tvHB0e
# 2689  spotify:track:53ann6bENp7BF8uklrzQAp
# 2690  spotify:track:0qFZYO72iBOhW7X6KbL44Q
#
#                                              track_href  \
# 0     https://api.spotify.com/v1/tracks/1ygVkGM0Uk0M...
# 1     https://api.spotify.com/v1/tracks/6U03Orwr5Dxt...
# 2     https://api.spotify.com/v1/tracks/2MzS7IK7ZXuk...
# 3     https://api.spotify.com/v1/tracks/4pSSmEzKzGo6...
# 4     https://api.spotify.com/v1/tracks/3LhM43JzrSMU...
# ...                                                 ...
# 2686  https://api.spotify.com/v1/tracks/4VVEfBXep7Fd...
# 2687  https://api.spotify.com/v1/tracks/7hOLwSaTSkrq...
# 2688  https://api.spotify.com/v1/tracks/76i4IBw3KsuD...
# 2689  https://api.spotify.com/v1/tracks/53ann6bENp7B...
# 2690  https://api.spotify.com/v1/tracks/0qFZYO72iBOh...
#
#                                            analysis_url  duration_ms  \
# 0     https://api.spotify.com/v1/audio-analysis/1ygV...       158173
# 1     https://api.spotify.com/v1/audio-analysis/6U03...       179293
# 2     https://api.spotify.com/v1/audio-analysis/2MzS...       118805
# 3     https://api.spotify.com/v1/audio-analysis/4pSS...       122044
# 4     https://api.spotify.com/v1/audio-analysis/3LhM...       116611
# ...                                                 ...          ...
# 2686  https://api.spotify.com/v1/audio-analysis/4VVE...       159320
# 2687  https://api.spotify.com/v1/audio-analysis/7hOL...       424653
# 2688  https://api.spotify.com/v1/audio-analysis/76i4...       249640
# 2689  https://api.spotify.com/v1/audio-analysis/53an...       256493
# 2690  https://api.spotify.com/v1/audio-analysis/0qFZ...       167640
#
#       time_signature  Unnamed: 0
# 0                  4         NaN
# 1                  4         NaN
# 2                  4         NaN
# 3                  4         NaN
# 4                  4         NaN
# ...              ...         ...
# 2686               4         NaN
# 2687               4         NaN
# 2688               4         NaN
# 2689               4         NaN
# 2690               3         NaN
#
# [2691 rows x 20 columns]

# %%
df = df.reset_index()

# %%
df["mode"].unique()
# Out:
# array([0, 1])

# %%
df["time_signature"].unique()
# Out:
# array([4, 3, 1, 5, 0])

# %%
X = df.drop(axis=1, columns=["index", "Unnamed: 0.1", "mode", "type", "id", "uri", "track_href", "analysis_url", "Unnamed: 0"], inplace=False, errors='raise')
X.head()
# Out:
#    danceability  energy  key  loudness  speechiness  acousticness  \
# 0         0.611   0.366    4   -10.890       0.2910         0.874
# 1         0.512   0.511    2    -8.645       0.0300         0.662
# 2         0.797   0.355   11   -14.592       0.0651         0.872
# 3         0.426   0.231    2   -16.066       0.0359         0.740
# 4         0.508   0.279    6   -15.586       0.0384         0.783
#
#    instrumentalness  liveness  valence    tempo  duration_ms  time_signature
# 0          0.000515    0.0838    0.593  146.052       158173               4
# 1          0.000199    0.2090    0.589   89.499       179293               4
# 2          0.000057    0.0857    0.961   87.574       118805               4
# 3          0.000000    0.1720    0.667  177.980       122044               4
# 4          0.000000    0.1400    0.728   83.261       116611               4

# %%
#Standardize the numerical features

std = StandardScaler()

X_scaled = std.fit_transform(X)
X_scaled = pd.DataFrame(X_scaled, columns=X.columns)

# %%
X_scaled.head()
# Out:
#    danceability    energy       key  loudness  speechiness  acousticness  \
# 0      0.035167 -1.087577 -0.330098 -0.470355     2.513100      1.786680
# 1     -0.517184 -0.495681 -0.886673 -0.061590    -0.656317      1.116901
# 2      1.072916 -1.132479  1.617914 -1.144406    -0.230085      1.780362
# 3     -0.997003 -1.638653 -0.886673 -1.412789    -0.584671      1.363329
# 4     -0.539501 -1.442715  0.226477 -1.325392    -0.554313      1.499181
#
#    instrumentalness  liveness   valence     tempo  duration_ms  time_signature
# 0         -0.403029 -0.655111  0.207233  0.854290    -0.558296        0.199469
# 1         -0.404275  0.192876  0.191506 -1.091088    -0.424868        0.199469
# 2         -0.404834 -0.642242  1.654132 -1.157306    -0.807007        0.199469
# 3         -0.405060 -0.057727  0.498186  1.952587    -0.786544        0.199469
# 4         -0.405060 -0.274465  0.738025 -1.305670    -0.820868        0.199469

# %%
# Save the scaler as a pickle file:
#with open('minmax.pkl', 'wb') as file:
    #pickle.dump(kmeans, file)

# Load the scaler from the pickle file
#with open('minmax.pkl', 'rb') as file:
    #minmax = pickle.load(file)

# %%
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn import metrics
from sklearn.metrics import silhouette_score
from sklearn.metrics import davies_bouldin_score
from sklearn.metrics import calinski_harabasz_score
from scipy.cluster.hierarchy import dendrogram, linkage
from sklearn.cluster import AgglomerativeClustering
from sklearn import cluster
from sklearn.cluster import DBSCAN
from sklearn.metrics import davies_bouldin_score
from sklearn.metrics import calinski_harabasz_score
import pickle

# %% [markdown]
# ## K-Means

# %%
#K-Means
silhouette = []

for k in range(10,30):
    kmeans = KMeans(n_clusters = k)
    kmeans.fit(X_scaled)
    labels = kmeans.predict(X_scaled)
    silhouette.append(silhouette_score(X_scaled, labels))

import matplotlib.pyplot as plt

plt.plot(range(10,30), silhouette, marker = "o")

# %%
kmeans = KMeans(n_clusters = 10, random_state=0)
kmeans.fit(X_scaled)
# Out:
# KMeans(n_clusters=10, random_state=0)

# %%
labels_km = kmeans.fit_predict(X_scaled)

# %% [markdown]
# ### Silhouette Score

# %%
sil_score_kmeans = silhouette_score(X_scaled, labels_km)
print(f"Silhouette Score for KMeans: {sil_score_kmeans}")
# Out:
# Silhouette Score for KMeans: 0.14246060989811238

# %% [markdown]
# ### Davies-Bouldin Index

# %%
db_score_km = davies_bouldin_score(X_scaled, labels_km)
print(f"Davies-Bouldin Index: {db_score_km}")
# Out:
# Davies-Bouldin Index: 1.4405011639425056

# %% [markdown]
# ### Calinski-Harabasz Index

# %%
ch_score_km = calinski_harabasz_score(X_scaled, labels_km)
print(f"Calinski-Harabasz Index: {ch_score_km}")
# Out:
# Calinski-Harabasz Index: 350.00811838846215

# %% [markdown]
# ## Hierarchical

# %%
#Hierarchical

silhouette = []

for k in range(10,20):
    agglomerative = cluster.AgglomerativeClustering(n_clusters=k,linkage='ward')
    agglomerative.fit(X_scaled)
    labels = agglomerative.fit_predict(X_scaled)
    silhouette.append(silhouette_score(X_scaled, labels))

import matplotlib.pyplot as plt

plt.plot(range(10,20), silhouette, marker = "o")

# %%
agglomerative = cluster.AgglomerativeClustering(n_clusters=11,linkage='ward')
labels_ward = agglomerative.fit_predict(X_scaled)

# %% [markdown]
# ### Silhouette Score

# %%
sil_score_agg_ward = silhouette_score(X_scaled, labels_ward)
print(f"Silhouette Score for Agglomerative Ward: {sil_score_agg_ward}")
# Out:
# Silhouette Score for Agglomerative Ward: 0.10718010014635988

# %% [markdown]
# ### Davies-Bouldin Index

# %%
db_score_ward = davies_bouldin_score(X_scaled, labels_ward)
print(f"Davies-Bouldin Index: {db_score_ward}")
# Out:
# Davies-Bouldin Index: 1.6805008944521007

# %% [markdown]
# ### Calinski-Harabasz Index

# %%
ch_score_ward = calinski_harabasz_score(X_scaled, labels_ward)
print(f"Calinski-Harabasz Index: {ch_score_ward}")
# Out:
# Calinski-Harabasz Index: 289.45564650856977

# %%
silhouette = []

for k in range(10,20):
    agglomerative = cluster.AgglomerativeClustering(n_clusters=k,linkage='complete')
    agglomerative.fit(X_scaled)
    labels = agglomerative.fit_predict(X_scaled)
    silhouette.append(silhouette_score(X_scaled, labels))

import matplotlib.pyplot as plt

plt.plot(range(10,20), silhouette, marker = "o")

# %% [markdown]
# ### Silhouette Score

# %%
agglomerative = cluster.AgglomerativeClustering(n_clusters=13,linkage='complete')
labels_compl = agglomerative.fit_predict(X_scaled)
sil_score_agg_compl = silhouette_score(X_scaled, labels)
print(f"Silhouette Score for Agglomerative Complete: {sil_score_agg_compl}")
# Out:
# Silhouette Score for Agglomerative Complete: 0.09332850985711512

# %% [markdown]
# ### Davies-Bouldin Index

# %%
db_score_agg_compl = davies_bouldin_score(X_scaled, labels_compl)
print(f"Davies-Bouldin Index: {db_score_agg_compl}")
# Out:
# Davies-Bouldin Index: 1.7002351470228478

# %% [markdown]
# ### Calinski-Harabasz Index

# %%
ch_score_compl = calinski_harabasz_score(X_scaled, labels_compl)
print(f"Calinski-Harabasz Index: {ch_score_compl}")
# Out:
# Calinski-Harabasz Index: 179.73770142205146

# %%
silhouette = []

for k in range(10,20):
    agglomerative = cluster.AgglomerativeClustering(n_clusters=k,linkage='single')
    agglomerative.fit(X_scaled)
    labels = agglomerative.fit_predict(X_scaled)
    silhouette.append(silhouette_score(X_scaled, labels))

import matplotlib.pyplot as plt

plt.plot(range(10,20), silhouette, marker = "o")

# %% [markdown]
# ### Silhouette Score

# %%
agglomerative = cluster.AgglomerativeClustering(n_clusters=10,linkage='single')
labels_single = agglomerative.fit_predict(X_scaled)
sil_score_agg_single = silhouette_score(X_scaled, labels)
print(f"Silhouette Score for Agglomerative Single: {sil_score_agg_single}")
# Out:
# Silhouette Score for Agglomerative Single: 0.22426274419802883

# %% [markdown]
# ### Davies-Bouldin Index

# %%
db_score_agg_single = davies_bouldin_score(X_scaled, labels_single)
print(f"Davies-Bouldin Index: {db_score_agg_single}")
# Out:
# Davies-Bouldin Index: 0.4910559222905406

# %% [markdown]
# ### Calinski-Harabasz Index

# %%
ch_score_single = calinski_harabasz_score(X_scaled, labels_single)
print(f"Calinski-Harabasz Index: {ch_score_single}")
# Out:
# Calinski-Harabasz Index: 19.770989679214114

# %% [markdown]
# ## DBSCAN

# %%
from sklearn.neighbors import NearestNeighbors
import matplotlib.pyplot as plt

#find best eps:
# Compute the k-nearest neighbors for each point
k = 10  # Number of neighbors to consider
nbrs = NearestNeighbors(n_neighbors=k).fit(X_scaled)
distances, indices = nbrs.kneighbors(X_scaled)
 
# Compute the average distance of the k-th nearest neighbor for each point
avg_distances = distances.mean(axis=1)
 
# Visualize the plot of k-nearest neighbors distance
plt.plot(sorted(avg_distances))
plt.xlabel('Point')
plt.ylabel(f'Average {k}-Nearest Neighbor Distance')
plt.title(f'{k}-Nearest Neighbor Distance Plot')
plt.show()

# %% [markdown]
# ### Silhouette Score

# %%
#Find the best min_samples

from sklearn.metrics import silhouette_score
import numpy as np
 
# Optimal value for eps
eps = 2.3
 
# Range of values for min_samples to explore
min_samples_range = range(2, 10)

# Initialize a list to save silhouette scores
silhouette_scores = []
 
# Compute silhouette score for each min_samples value
for min_samples in min_samples_range:
    dbscan = DBSCAN(eps=eps, min_samples=min_samples)
    labels = dbscan.fit_predict(X_scaled)
    if len(np.unique(labels)) > 1:  # Ensure there are at least 2 clusters
        silhouette_avg = silhouette_score(X_scaled, labels)
        silhouette_scores.append(silhouette_avg)
    else:
        silhouette_scores.append(-1)  # Set a negative score if there's only one cluster
 
# Find the min_samples value with the maximum silhouette score
best_min_samples = min_samples_range[np.argmax(silhouette_scores)]
best_silhouette_score = max(silhouette_scores)
 
print(f"The best value for min_samples is {best_min_samples} with a silhouette score of {best_silhouette_score}")
# Out:
# The best value for min_samples is 6 with a silhouette score of 0.15384120089717526

# %%
dbs = cluster.DBSCAN(eps=2.3, min_samples = 6)

pred = dbs.fit_predict(X_scaled)
pred
# Out:
# array([0, 0, 0, ..., 0, 0, 1])

# %%
pred= pd.DataFrame(pred)

# %%
pred.value_counts()
# Out:
#  0    2405
# -1     159
#  1      92
#  2      35
# Name: count, dtype: int64

# %% [markdown]
# ### Davies-Bouldin Index

# %%
db_score_dbs = davies_bouldin_score(X_scaled, pred)
print(f"Davies-Bouldin Index: {db_score_dbs}")
# Out:
# Davies-Bouldin Index: 2.3618268816545482
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:1339: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %% [markdown]
# ### Calinski-Harabasz Index

# %%
ch_score_dbs = calinski_harabasz_score(X_scaled, pred)
print(f"Calinski-Harabasz Index: {ch_score_dbs}")
# Out:
# Calinski-Harabasz Index: 125.29682757059336
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:1339: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %% [markdown]
# ## K-Means

# %%
pred = kmeans.predict(X_scaled)
pred = pd.DataFrame(pred)
pred
# Out:
#       0
# 0     5
# 1     3
# 2     3
# 3     3
# 4     3
# ...  ..
# 2686  2
# 2687  2
# 2688  2
# 2689  2
# 2690  2
#
# [2691 rows x 1 columns]

# %%
X["cluster"] = pred
X
# Out:
#       danceability  energy  key  loudness  speechiness  acousticness  \
# 0           0.6110  0.3660    4   -10.890       0.2910         0.874
# 1           0.5120  0.5110    2    -8.645       0.0300         0.662
# 2           0.7970  0.3550   11   -14.592       0.0651         0.872
# 3           0.4260  0.2310    2   -16.066       0.0359         0.740
# 4           0.5080  0.2790    6   -15.586       0.0384         0.783
# ...            ...     ...  ...       ...          ...           ...
# 2686        0.2400  0.0834    6   -29.545       0.0499         0.978
# 2687        0.4050  0.3180    9   -17.140       0.0565         0.938
# 2688        0.2910  0.0981    8   -23.156       0.0398         0.950
# 2689        0.0992  0.2260    9   -14.840       0.0339         0.937
# 2690        0.3390  0.0937    2   -20.267       0.0394         0.931
#
#       instrumentalness  liveness  valence    tempo  duration_ms  \
# 0             0.000515    0.0838   0.5930  146.052       158173
# 1             0.000199    0.2090   0.5890   89.499       179293
# 2             0.000057    0.0857   0.9610   87.574       118805
# 3             0.000000    0.1720   0.6670  177.980       122044
# 4             0.000000    0.1400   0.7280   83.261       116611
# ...                ...       ...      ...      ...          ...
# 2686          0.944000    0.0804   0.1880  169.621       159320
# 2687          0.723000    0.2840   0.3420  151.434       424653
# 2688          0.865000    0.2750   0.1940  138.168       249640
# 2689          0.903000    0.1830   0.0605   79.518       256493
# 2690          0.293000    0.2520   0.4580  123.048       167640
#
#       time_signature  cluster
# 0                  4        5
# 1                  4        3
# 2                  4        3
# 3                  4        3
# 4                  4        3
# ...              ...      ...
# 2686               4        2
# 2687               4        2
# 2688               4        2
# 2689               4        2
# 2690               3        2
#
# [2691 rows x 13 columns]

# %%
X.groupby(["cluster"]).mean()
# Out:
#          danceability    energy       key   loudness  speechiness  \
# cluster
# 0            0.483109  0.767841  5.393182  -5.917880     0.064661
# 1            0.710216  0.722353  1.870909  -6.062027     0.063797
# 2            0.256430  0.115147  5.387283 -23.133266     0.044190
# 3            0.570618  0.389595  4.613333 -11.159509     0.047465
# 4            0.488944  0.393394  5.666667 -11.916889     0.094611
# 5            0.698086  0.679102  5.236735  -6.521804     0.295637
# 6            0.704556  0.732712  8.732448  -6.170455     0.067624
# 7            0.654532  0.830317  5.436508  -7.513079     0.071713
# 8            0.589058  0.712449  5.601449  -7.044739     0.097841
# 9            0.334083  0.372821  4.208333 -17.025625     0.054950
#
#          acousticness  instrumentalness  liveness   valence       tempo  \
# cluster
# 0            0.098097          0.020348  0.163122  0.426245  146.527036
# 1            0.170509          0.017434  0.150753  0.690250  114.377733
# 2            0.917272          0.736628  0.128795  0.166015  101.851659
# 3            0.654919          0.025680  0.144712  0.476727  114.977702
# 4            0.649094          0.210521  0.207094  0.396467  104.788556
# 5            0.214407          0.007787  0.182492  0.562023  130.161837
# 6            0.191913          0.010107  0.157005  0.698477  113.527078
# 7            0.132091          0.733460  0.162066  0.346798  132.743381
# 8            0.294791          0.035616  0.632101  0.584625  119.402551
# 9            0.712042          0.437977  0.202821  0.257971  110.344667
#
#           duration_ms  time_signature
# cluster
# 0        2.446974e+05        3.922727
# 1        2.118815e+05        3.996364
# 2        3.686097e+05        3.745665
# 3        2.291721e+05        3.900000
# 4        3.062827e+05        0.944444
# 5        2.134727e+05        3.991837
# 6        2.148087e+05        3.990512
# 7        2.652581e+05        3.984127
# 8        2.285452e+05        3.992754
# 9        1.515535e+06        3.916667
